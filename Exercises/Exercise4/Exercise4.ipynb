# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
# Load and look at the data

Data = pd.read_csv('../Teoph.csv')
Data
# Out:
#      Subject    Wt  Dose   Time   conc
# 0          1  79.6  4.02   0.00   0.74
# 1          1  79.6  4.02   0.25   2.84
# 2          1  79.6  4.02   0.57   6.57
# 3          1  79.6  4.02   1.12  10.50
# 4          1  79.6  4.02   2.02   9.66
# ..       ...   ...   ...    ...    ...
# 127       12  60.5  5.30   5.07   8.57
# 128       12  60.5  5.30   7.07   6.59
# 129       12  60.5  5.30   9.03   6.11
# 130       12  60.5  5.30  12.05   4.57
# 131       12  60.5  5.30  24.15   1.17
#
# [132 rows x 5 columns]

# %%
# Plot for each subject

Figure, Axis = plt.subplots(1,1)
for Label, DataFrame in Data.groupby('Subject'):
    DataFrame.plot(x='Time', y='conc', ax=Axis, label=Label,
                   marker='o', fillstyle='none', linestyle='--')
Axis.set_xlabel('Time (hours)')
Axis.set_ylabel('Concentration (mg/l)')
plt.legend(title='Subject', bbox_to_anchor=(1.05,1))
plt.show()

# %%
LME = smf.mixedlm('conc ~ Dose * np.exp(Phi1) * np.exp(Phi2) / (np.exp(Phi3) * (np.exp(Phi2) - np.exp(Phi1))) * (np.exp(-np.exp(Phi1)*Time) - np.exp(-np.exp(Phi2)*Time))',
                        # vc_formula={'Block': '1', 'Variety': '0 + Variety'},
                        data=Data,
                        groups=Data['Subject'],
                        ).fit(reml=True)
print(LME.summary())
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       2 Data['Phi2'] = 1
#       3 Data['Phi3'] = 1
# ----> 4 LME = smf.mixedlm('conc ~ Dose * np.exp(Phi1) * np.exp(Phi2) / (np.exp(Phi3) * (np.exp(Phi2) - np.exp(Phi1))) * (np.exp(-np.exp(Phi1)*Time) - np.exp(-np.exp(Phi2)*Time))',
#       5                         # vc_formula={'Block': '1', 'Variety': '0 + Variety'},
#       6                         data=Data,
#       7                         groups=Data['Subject'],
#       8                         ).fit(reml=True)
#       9 print(LME.summary())
#
# File ~\anaconda3\envs\PhD\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2191, in MixedLM.fit(self, start_params, reml, niter_sa, do_cg, fe_pen, cov_pen, free, full_output, method, **fit_kwargs)
#    2189 # Try optimizing one or more times
# ...

# %%
Parameters = Oats_LMM1.params
Scale = Oats_LMM1.scale

print(Parameters[:-2])
print((Parameters[-2:] * Scale) ** 0.5)
# Out:
# Intercept    81.872222
# nitro        73.666667
# dtype: float64
# Block Var      14.506172
# Variety Var    11.004807
# dtype: float64

# %%
X = Oats_LMM1.model.exog
nij = Oats_LMM1.
# Out:
# array([[1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
#        [1. , 0.6],
#        [1. , 0. ],
#        [1. , 0.2],
#        [1. , 0.4],
# ...
